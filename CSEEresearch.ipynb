# %% [markdown]
# <a href="https://colab.research.google.com/github/shayanmazhar/Build-and-Deploy-Ecommerce-Website/blob/main/CSEEresearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install kaggle to get the dataset from Kaggle (if not installed)
# !pip install kaggle

# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-58bdbfe8-a95b-4a8e-9d15-051ba6ffd0be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58bdbfe8-a95b-4a8e-9d15-051ba6ffd0be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Make a directory for the Kaggle API key
# !mkdir ~/.kaggle

# Copy kaggle.json into the .kaggle directory
# !cp kaggle.json ~/.kaggle/

# Set the required permissions for the API key file
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d naserabdullahalam/phishing-email-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/naserabdullahalam/phishing-email-dataset
# License(s): CC-BY-SA-4.0
# phishing-email-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip phishing-email-dataset.zip
# Out:
# Archive:  phishing-email-dataset.zip
# replace CEAS_08.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: CEAS_08.csv
# replace Enron.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Enron.csv
# replace Ling.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Ling.csv
# replace Nazario.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Nazario.csv
# replace Nigerian_Fraud.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: Nigerian_Fraud.csv
# replace SpamAssasin.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: SpamAssasin.csv
# replace phishing_email.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: phishing_email.csv

# %%
# !ls
# Out:
# CEAS_08.csv  Ling.csv	  Nigerian_Fraud.csv  phishing-email-dataset.zip  SpamAssasin.csv
# Enron.csv    Nazario.csv  phishing_email.csv  sample_data

# %%
# import pandas as pd

# # Load the individual datasets into DataFrames
# df_enron = pd.read_csv('Enron.csv')
# df_ling = pd.read_csv('Ling.csv')
# df_ceas = pd.read_csv('CEAS_08.csv')
# df_nazario = pd.read_csv('Nazario.csv')
# df_nigerian_fraud = pd.read_csv('Nigerian_Fraud.csv')
# df_spamassasin = pd.read_csv('SpamAssasin.csv')
# df_phishing = pd.read_csv('phishing_email.csv')

# # # Display the first few rows of each dataset (optional)
# # print("Enron Dataset:")
# # print(df_enron.head(), "\n")

# # print("Ling Dataset:")
# # print(df_ling.head(), "\n")

# # print("CEAS Dataset:")
# # print(df_ceas.head(), "\n")

# # print("Nazario Dataset:")
# # print(df_nazario.head(), "\n")

# # print("Nigerian Fraud Dataset:")
# # print(df_nigerian_fraud.head(), "\n")

# # print("SpamAssassin Dataset:")
# # print(df_spamassasin.head(), "\n")

# # print("Phishing Email Dataset:")
# # print(df_phishing.head(), "\n")

# # Merge the Enron and Ling datasets
# df_enron_ling = pd.concat([df_enron, df_ling], ignore_index=True)
# print("Merged Enron and Ling Datasets:")
# print(df_enron_ling.head(), "\n")

# # Merge CEAS, Nazario, Nigerian Fraud, and SpamAssassin datasets
# df_ceas_nazario_fraud_spam = pd.concat([df_ceas, df_nazario, df_nigerian_fraud, df_spamassasin], ignore_index=True)
# print("Merged CEAS, Nazario, Nigerian Fraud, and SpamAssassin Datasets:")
# print(df_ceas_nazario_fraud_spam.head(), "\n")

# # # Optionally, you can save the merged DataFrames to CSV files for later use
# # df_enron_ling.to_csv('merged_enron_ling.csv', index=False)
# # df_ceas_nazario_fraud_spam.to_csv('merged_ceas_nazario_fraud_spam.csv', index=False)

# # Check for necessary columns in the merged datasets (such as 'email_content' and 'label')
# print("Columns in  Ling  dataset:")
# print(df_enron_ling.columns)

# print("Columns in CEAS + Nazario + Nigerian Fraud + SpamAssassin merged dataset:")
# print(df_ceas_nazario_fraud_spam.columns)

# print("Columns in phishing email dataset:")
# print(df_phishing.columns)

# # Ensure both merged datasets have a 'label' column for classification
# # Assuming there's a column called 'label' that indicates phishing (1) or non-phishing (0)
# # If not, you may need to manually create the 'label' column, depending on the dataset structure

# # Checking for missing values or inconsistencies
# print("Missing values in Ling dataset:")
# print(df_enron_ling.isnull().sum())

# print("Missing values in CEAS + Nazario + Fraud + SpamAssassin dataset:")
# print(df_ceas_nazario_fraud_spam.isnull().sum())

# print("Missing values in phishing email dataset:")
# print(df_phishing.isnull().sum())

# # Drop rows with missing labels (if any)
# df_enron_ling.dropna(subset=['label'], inplace=True)
# df_ceas_nazario_fraud_spam.dropna(subset=['label'], inplace=True)
# df_ceas_nazario_fraud_spam.dropna(subset=['body'], inplace=True)
# df_phishing.dropna(subset=['label'], inplace=True)

# # After ensuring the structure is consistent, now these datasets are ready for training
# Out:
# Merged Enron and Ling Datasets:
#                                       subject  \
# 0                   hpl nom for may 25 , 2001
# 1            re : nom / actual vols for 24 th
# 2  enron actuals for march 30 - april 1 , 201
# 3                   hpl nom for may 30 , 2001
# 4                   hpl nom for june 1 , 2001
#
#                                                 body  label
# 0  ( see attached file : hplno 525 . xls )\r\n- h...      0
# 1  - - - - - - - - - - - - - - - - - - - - - - fo...      0
# 2  estimated actuals\r\nmarch 30 , 2001\r\nno flo...      0
# 3  ( see attached file : hplno 530 . xls )\r\n- h...      0
# 4  ( see attached file : hplno 601 . xls )\r\n- h...      0
#
# Merged CEAS, Nazario, Nigerian Fraud, and SpamAssassin Datasets:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# ...

# %%
import pandas as pd

# Load individual datasets into DataFrames
df_enron = pd.read_csv('/content/Enron.csv')
df_ling = pd.read_csv('/content/Ling.csv')
df_ceas = pd.read_csv('/content/CEAS_08.csv')
df_nazario = pd.read_csv('/content/Nazario.csv')
df_fraud = pd.read_csv('/content/Nigerian_Fraud.csv')
df_spamassassin = pd.read_csv('/content/SpamAssasin.csv')
df_phishing = pd.read_csv('/content/phishing_email.csv')

# Merge Enron and Ling datasets
df_enron_ling = pd.concat([df_enron, df_ling], ignore_index=True)

# Merge CEAS, Nazario, Fraud, and SpamAssassin datasets
df_ceas_nazario_fraud_spam = pd.concat([df_ceas, df_nazario, df_fraud, df_spamassassin], ignore_index=True)

#  Drop rows with missing labels (if any)
df_enron_ling.dropna(subset=['label'], inplace=True)
df_ceas_nazario_fraud_spam.dropna(subset=['label'], inplace=True)
df_ceas_nazario_fraud_spam.dropna(subset=['body'], inplace=True)
df_phishing.dropna(subset=['label'], inplace=True)

# Combine all datasets for consistent vectorization
combined_texts = df_enron_ling['body'].tolist() + df_ceas_nazario_fraud_spam['body'].tolist() + df_phishing['text_combined'].tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Use TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the combined text data
vectorizer.fit(combined_texts)

# Transform each dataset using the same vectorizer
X_train_enron_ling = vectorizer.transform(df_enron_ling['body'])
X_train_ceas_nazario_fraud_spam = vectorizer.transform(df_ceas_nazario_fraud_spam['body'])
X_test_phishing = vectorizer.transform(df_phishing['text_combined'])

# Labels (assuming your datasets have a 'label' column where 1 = phishing, 0 = non-phishing)
y_train_enron_ling = df_enron_ling['label']
y_train_ceas_nazario_fraud_spam = df_ceas_nazario_fraud_spam['label']
y_test_phishing = df_phishing['label']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Train Logistic Regression model on Enron + Ling
logreg_enron_ling = LogisticRegression(max_iter=32626)
logreg_enron_ling.fit(X_train_enron_ling, y_train_enron_ling)

# Train Logistic Regression model on CEAS + Nazario + Fraud + SpamAssassin
logreg_ceas_nazario_fraud_spam = LogisticRegression(max_iter=10706)
logreg_ceas_nazario_fraud_spam.fit(X_train_ceas_nazario_fraud_spam, y_train_ceas_nazario_fraud_spam)
# Out:
# LogisticRegression(max_iter=10706)

# %%
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest on Enron + Ling
rf_enron_ling = RandomForestClassifier(n_estimators=100, random_state=42)
rf_enron_ling.fit(X_train_enron_ling, y_train_enron_ling)

# Train Random Forest on CEAS + Nazario + Fraud + SpamAssassin
rf_ceas_nazario_fraud_spam = RandomForestClassifier(n_estimators=100, random_state=42)
rf_ceas_nazario_fraud_spam.fit(X_train_ceas_nazario_fraud_spam, y_train_ceas_nazario_fraud_spam)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict with Logistic Regression models
y_pred_enron_ling_logreg = logreg_enron_ling.predict(X_test_phishing)
y_pred_ceas_nazario_fraud_spam_logreg = logreg_ceas_nazario_fraud_spam.predict(X_test_phishing)

# Evaluate accuracy
accuracy_enron_ling_logreg = accuracy_score(y_test_phishing, y_pred_enron_ling_logreg)
accuracy_ceas_nazario_fraud_spam_logreg = accuracy_score(y_test_phishing, y_pred_ceas_nazario_fraud_spam_logreg)

print(f"Logistic Regression Accuracy - Enron + Ling: {accuracy_enron_ling_logreg}")
print(f"Logistic Regression Accuracy - CEAS + Nazario + Fraud + SpamAssassin: {accuracy_ceas_nazario_fraud_spam_logreg}")
# Out:
# Logistic Regression Accuracy - Enron + Ling: 0.7808476589966782
# Logistic Regression Accuracy - CEAS + Nazario + Fraud + SpamAssassin: 0.8788885386611062

# %%
# Predict with Random Forest models
y_pred_enron_ling_rf = rf_enron_ling.predict(X_test_phishing)
y_pred_ceas_nazario_fraud_spam_rf = rf_ceas_nazario_fraud_spam.predict(X_test_phishing)

# Evaluate accuracy
accuracy_enron_ling_rf = accuracy_score(y_test_phishing, y_pred_enron_ling_rf)
accuracy_ceas_nazario_fraud_spam_rf = accuracy_score(y_test_phishing, y_pred_ceas_nazario_fraud_spam_rf)

print(f"Random Forest Accuracy - Enron + Ling: {accuracy_enron_ling_rf}")
print(f"Random Forest Accuracy - CEAS + Nazario + Fraud + SpamAssassin: {accuracy_ceas_nazario_fraud_spam_rf}")
# Out:
# Random Forest Accuracy - Enron + Ling: 0.8459738622311666
# Random Forest Accuracy - CEAS + Nazario + Fraud + SpamAssassin: 0.8487985840021337

# %%
# Confusion matrix for Logistic Regression
conf_matrix_enron_ling_logreg = confusion_matrix(y_test_phishing, y_pred_enron_ling_logreg)
conf_matrix_ceas_nazario_fraud_spam_logreg = confusion_matrix(y_test_phishing, y_pred_ceas_nazario_fraud_spam_logreg)

print("Confusion Matrix for Enron + Ling Logistic Regression:")
print(conf_matrix_enron_ling_logreg)
print("Confusion Matrix for CEAS + Nazario + Fraud + SpamAssassin Logistic Regression:")
print(conf_matrix_ceas_nazario_fraud_spam_logreg)

# Confusion matrix for Random Forest
conf_matrix_enron_ling_rf = confusion_matrix(y_test_phishing, y_pred_enron_ling_rf)
conf_matrix_ceas_nazario_fraud_spam_rf = confusion_matrix(y_test_phishing, y_pred_ceas_nazario_fraud_spam_rf)

print("Confusion Matrix for Enron + Ling Random Forest:")
print(conf_matrix_enron_ling_rf)
print("Confusion Matrix for CEAS + Nazario + Fraud + SpamAssassin Random Forest:")
print(conf_matrix_ceas_nazario_fraud_spam_rf)


#  To better understand the confusion matrix
tn, fp, fn, tp = confusion_matrix(y_test_phishing, y_pred_enron_ling).ravel()
print(f"Enron + Ling Model - False Positives: {fp}, False Negatives: {fn}")

tn, fp, fn, tp = confusion_matrix(y_test_phishing, y_pred_ceas_nazario_fraud_spam).ravel()
print(f"CEAS + Nazario + Fraud + SpamAssassin Model - False Positives: {fp}, False Negatives: {fn}")
# Out:
# Confusion Matrix for Enron + Ling Logistic Regression:
# [[21677 17918]
#  [  159 42732]]
# Confusion Matrix for CEAS + Nazario + Fraud + SpamAssassin Logistic Regression:
# [[30411  9184]
#  [  806 42085]]
# Confusion Matrix for Enron + Ling Random Forest:
# [[29652  9943]
#  [ 2762 40129]]
# Confusion Matrix for CEAS + Nazario + Fraud + SpamAssassin Random Forest:
# [[32542  7053]
#  [ 5419 37472]]
